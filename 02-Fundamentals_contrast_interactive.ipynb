# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as ipw

# %%
np.random.seed(0)

X,Y = np.meshgrid(np.arange(10),np.arange(10))
val = 100*np.exp(-(X-3)**2/10 - (Y-5)**2/10) + np.random.randn(10,10)
val[val<0] = 0

sample = np.round(val)

# %%
def plot_range(range_values, sample):

    fig, ax = plt.subplots(figsize=(8,8))
    plt.imshow(sample, cmap = 'gray', vmin = range_values[0], vmax = range_values[1])
    for i in range(sample.shape[0]):
        for j in range(sample.shape[1]):
            plt.text(s = str(sample[i,j].astype(int)), x = j, y = i, fontdict={'fontsize':20},
                     horizontalalignment='center', verticalalignment='center', color = 'red')
    ax.set_xticks(np.arange(11))
    ax.set_yticks(np.arange(11))
    #fig.set_tight_layout(True)
    ax.set_axis_off()
    plt.show()

# %%
ipw.interact(plot_range, range_values = ipw.IntRangeSlider(min = 0, max = 150), sample = ipw.fixed(sample));
# Out:
# interactive(children=(IntRangeSlider(value=(37, 112), description='range_values', max=150), Output()), _dom_cl…

# %%
# %matplotlib notebook

# %%
fig, ax = plt.subplots(figsize=(8,8))
imfig = plt.imshow(sample, cmap = 'gray', vmin = 0, vmax = 150)
for i in range(sample.shape[0]):
    for j in range(sample.shape[1]):
        plt.text(s = str(sample[i,j].astype(int)), x = j, y = i, fontdict={'fontsize':20},
                 horizontalalignment='center', verticalalignment='center', color = 'red')
ax.set_xticks(np.arange(11))
ax.set_yticks(np.arange(11))
#fig.set_tight_layout(True)
ax.set_axis_off()
plt.show()

def plot_range(range_values, imfig):

    imfig.set_clim(range_values[0],range_values[1])
    plt.show()
    
ipw.interact(plot_range, range_values = ipw.IntRangeSlider(min = 0, max = 150, description = 'Range'), imfig = ipw.fixed(imfig));
# Out:
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(IntRangeSlider(value=(37, 112), description='Range', max=150), Output()), _dom_classes=(…
